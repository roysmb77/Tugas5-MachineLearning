# %%
# === Import Library ===
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# === Baca Dataset ===
df = pd.read_csv("health_lifestyle_dataset.csv")

# === Menampilkan 5 Baris Pertama ===
print("--- 5 Baris Pertama Data ---")
print(df.head())

# === Informasi Umum Dataset ===
print("\n--- Informasi Dataset ---")
print(df.info())

# === Statistik Deskriptif ===
print("\n--- Statistik Deskriptif ---")
print(df.describe(include='all'))

# === Visualisasi Distribusi Target ===
plt.figure(figsize=(6, 4))
sns.countplot(x='risiko_penyakit', data=df, palette='Greens')
plt.title('Distribusi Risiko Penyakit (1 = Berisiko, 0 = Tidak Berisiko)')
plt.xlabel('Status Risiko Penyakit')
plt.ylabel('Jumlah Individu')
plt.show()
# Out:
# --- 5 Baris Pertama Data ---
#    id  usia jenis_kelamin  indeks_massa_tubuh  langkah_harian  jam_tidur  \
# 0   1    56          Male                20.5            4198        3.9
# 1   2    69        Female                33.3           14359        9.0
# 2   3    46          Male                31.6            1817        6.6
# 3   4    32        Female                38.2           15772        3.6
# 4   5    60        Female                33.6            6037        3.8
#
#    air_minum_per_hari  asupan_kalori_harian  perokok  alkohol  denyut_jantung  \
# 0                 3.4                  1602        0        0              97
# 1                 4.7                  2346        0        1              68
# 2                 4.2                  1643        0        1              90
# 3                 2.0                  2460        0        0              71
# 4                 4.0                  3756        0        1              98
#
#    systolic_bp  diastolic_bp  kolesterol  riwayat_keluarga  risiko_penyakit
# 0          161           111         240                 0                0
# 1          116            65         207                 0                0
# 2          123            99         296                 0                0
# 3          165            95         175                 0                0
# 4          139            61         294                 0                0
#
# --- Informasi Dataset ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    100000 non-null  int64
#  1   usia                  100000 non-null  int64
#  2   jenis_kelamin         100000 non-null  object
#  3   indeks_massa_tubuh    100000 non-null  float64
#  4   langkah_harian        100000 non-null  int64
#  5   jam_tidur             100000 non-null  float64
#  6   air_minum_per_hari    100000 non-null  float64
#  7   asupan_kalori_harian  100000 non-null  int64
#  8   perokok               100000 non-null  int64
#  9   alkohol               100000 non-null  int64
#  10  denyut_jantung        100000 non-null  int64
#  11  systolic_bp           100000 non-null  int64
#  12  diastolic_bp          100000 non-null  int64
#  13  kolesterol            100000 non-null  int64
#  14  riwayat_keluarga      100000 non-null  int64
#  15  risiko_penyakit       100000 non-null  int64
# dtypes: float64(3), int64(12), object(1)
# memory usage: 12.2+ MB
# None
#
# --- Statistik Deskriptif ---
#                    id           usia jenis_kelamin  indeks_massa_tubuh  \
# count   100000.000000  100000.000000        100000       100000.000000
# unique            NaN            NaN             2                 NaN
# top               NaN            NaN          Male                 NaN
# freq              NaN            NaN         50132                 NaN
# mean     50000.500000      48.525990           NaN           29.024790
# std      28867.657797      17.886768           NaN            6.352666
# min          1.000000      18.000000           NaN           18.000000
# 25%      25000.750000      33.000000           NaN           23.500000
# 50%      50000.500000      48.000000           NaN           29.000000
# 75%      75000.250000      64.000000           NaN           34.500000
# max     100000.000000      79.000000           NaN           40.000000
#
#         langkah_harian      jam_tidur  air_minum_per_hari  \
# count     100000.00000  100000.000000       100000.000000
# unique             NaN            NaN                 NaN
# top                NaN            NaN                 NaN
# freq               NaN            NaN                 NaN
# mean       10479.87029       6.491784            2.751496
# std         5483.63236       2.021922            1.297338
# min         1000.00000       3.000000            0.500000
# 25%         5729.00000       4.700000            1.600000
# 50%        10468.00000       6.500000            2.800000
# 75%        15229.00000       8.200000            3.900000
# max        19999.00000      10.000000            5.000000
#
#         asupan_kalori_harian        perokok        alkohol  denyut_jantung  \
# count          100000.000000  100000.000000  100000.000000   100000.000000
# unique                   NaN            NaN            NaN             NaN
# top                      NaN            NaN            NaN             NaN
# freq                     NaN            NaN            NaN             NaN
# mean             2603.341200       0.200940       0.300020       74.457420
# std               807.288563       0.400705       0.458269       14.423715
# min              1200.000000       0.000000       0.000000       50.000000
# 25%              1906.000000       0.000000       0.000000       62.000000
# 50%              2603.000000       0.000000       0.000000       74.000000
# 75%              3299.000000       0.000000       1.000000       87.000000
# max              3999.000000       1.000000       1.000000       99.000000
#
#          systolic_bp   diastolic_bp     kolesterol  riwayat_keluarga  \
# count   100000.00000  100000.000000  100000.000000     100000.000000
# unique           NaN            NaN            NaN               NaN
# top              NaN            NaN            NaN               NaN
# freq             NaN            NaN            NaN               NaN
# mean       134.58063      89.508850     224.300630          0.299150
# std         25.95153      17.347041      43.327749          0.457888
# min         90.00000      60.000000     150.000000          0.000000
# 25%        112.00000      74.000000     187.000000          0.000000
# 50%        135.00000      89.000000     224.000000          0.000000
# 75%        157.00000     105.000000     262.000000          1.000000
# max        179.00000     119.000000     299.000000          1.000000
#
#         risiko_penyakit
# count     100000.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           0.248210
# std            0.431976
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000
# C:\Users\royba\AppData\Local\Temp\ipykernel_3708\1955493028.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='risiko_penyakit', data=df, palette='Greens')
